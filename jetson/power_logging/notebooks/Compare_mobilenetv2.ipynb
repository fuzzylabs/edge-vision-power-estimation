# %%
import pandas as pd
import matplotlib.pyplot as plt

DATA_PATH = '../raw_data/mobilenet_v2_data'
avg_cols = ['average_power', 'average_run_time']

# %%
trt_df = pd.read_csv(f'{DATA_PATH}/trt_mobilenet_v2_average_power_stats.csv')

# %%
trt_df['layer_name'] = trt_df['layer_name'].apply(lambda x : x.split(' + ')[0].split('-')[-1].replace('[', '').replace(']', ''))

# %%
subset_df = trt_df[['layer_name', 'average_power']]
subset_df['average_power'] = subset_df['average_power'] * 1e-3
subset_df.groupby(by=['layer_name'], sort=False).boxplot(subplots=False, figsize=(25, 10), rot=90, showfliers=False).set_ylabel('Power mW (milliWatts)')
plt.show()
# Out:
# /tmp/ipykernel_349448/2915600730.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['average_power'] = subset_df['average_power'] * 1e-3

# %%
subset_df = trt_df[['layer_name', 'average_run_time']]
subset_df.groupby(by=['layer_name'], sort=False).boxplot(subplots=False, figsize=(25, 10), rot=90, showfliers=False).set_ylabel('Latency (ms)')
plt.show()

# %%
subset_df = trt_df[['layer_name', 'average_power', 'average_run_time']]
subset_df['average_power'] = subset_df['average_power'] * 1e-3 # microwatts to millwats
subset_df['average_run_time'] = subset_df['average_run_time'] * 1e-3 # milliseconds to seconds
subset_df['average_energy'] = subset_df['average_power'] * subset_df['average_run_time']
subset_df = subset_df[['layer_name', 'average_energy']]
subset_df.groupby(by=['layer_name'], sort=False).boxplot(subplots=False, figsize=(25, 10), rot=90, showfliers=False).set_ylabel('Energy MWs (MilliWattSec)')
plt.show()
# Out:
# /tmp/ipykernel_349448/304811235.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['average_power'] = subset_df['average_power'] * 1e-3 # microwatts to millwats
# /tmp/ipykernel_349448/304811235.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['average_run_time'] = subset_df['average_run_time'] * 1e-3 # milliseconds to seconds
# /tmp/ipykernel_349448/304811235.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
pt_df = pd.read_csv(f'{DATA_PATH}/mobilenet_v2_average_run_time_stats.csv')

# %%
subset_df = pt_df[['layer_name', 'average_power']]
subset_df['average_power'] = subset_df['average_power'] * 1e-3
subset_df.groupby(by=['layer_name'], sort=False).boxplot(subplots=False, figsize=(25, 10), rot=90, showfliers=False).set_ylabel('Power mW (milliWatts)')
plt.show()
# Out:
# /tmp/ipykernel_349448/1328277711.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['average_power'] = subset_df['average_power'] * 1e-3

# %%
subset_df = pt_df[['layer_name', 'average_run_time']]
subset_df.groupby(by=['layer_name'], sort=False).boxplot(subplots=False, figsize=(25, 10), rot=90, showfliers=False).set_ylabel('Latency (ms)')
plt.show()

# %%
subset_df = pt_df[['layer_name', 'average_power', 'average_run_time']]
subset_df['average_power'] = subset_df['average_power'] * 1e-3 # microwatts to millwats
subset_df['average_run_time'] = subset_df['average_run_time'] * 1e-3 # milliseconds to seconds
subset_df['average_energy'] = subset_df['average_power'] * subset_df['average_run_time']
subset_df = subset_df[['layer_name', 'average_energy']]
subset_df.groupby(by=['layer_name'], sort=False).boxplot(subplots=False, figsize=(25, 10), rot=90, showfliers=False).set_ylabel('Energy MWs (MilliWattSec)')
plt.show()
# Out:
# /tmp/ipykernel_349448/3150615924.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['average_power'] = subset_df['average_power'] * 1e-3 # microwatts to millwats
# /tmp/ipykernel_349448/3150615924.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['average_run_time'] = subset_df['average_run_time'] * 1e-3 # milliseconds to seconds
# /tmp/ipykernel_349448/3150615924.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
